# %% [markdown]
# # Causal Modeling DML - Modeling Selection & Validation

# %% [markdown]
# Author: Lujun LI

# %% [markdown]
# Based on the data we have, we primarily use DML as our CATE estimation framework. Our goal is to find the best model for different scenarios.
#
# The basic framework we use is from EconML, which includes:
# - Linear DML
# - Sparse Linear DML
# - NoParamDML
# - Causal Forest DML
#
# The model functions we use are mainly chosen from:
# - Linear Regression
# - Lasso
# - Ridge Regression
# - Random Forest Regressor
# - XGBoost Regressor
# - LGBM Regressor
#
# For validation, we mainly use R score, MAPE, and the score function to evaluate model performance. We divide the interventional data into 60% training data and 40% validation data.
#
# Grid Search will be used for hyperparameter tuning to find the best hyperparameters for each model. The `model_y`, `model_t`, and `model_final` may use different fitting models.
#
# The estimation of marginal CATE will be obtained at different temperatures, and then the shape values will be used for further explanation.

# %%
from econml.dml import DML, LinearDML, SparseLinearDML, CausalForestDML
import numpy as np
from itertools import product
from sklearn.linear_model import (Lasso, LassoCV, LogisticRegression,
                                  LogisticRegressionCV,LinearRegression,
                                  MultiTaskElasticNet,MultiTaskElasticNetCV)
from sklearn.ensemble import RandomForestRegressor,RandomForestClassifier
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt
import matplotlib
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %% [markdown]
# Let's import a test set and try to run normally every model we want to check

# %%
import os
import datetime
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


current_time = datetime.datetime.now()
current_time_str = current_time.strftime("%Y%m%d%H%M%S")
model_weight_sizes = {
    "Llama-2-13b-chat-hf": 13,
    "Mistral-7B-Instruct-v0.2": 7,
    "Llama-2-70b-chat-hf": 70,
    "Meta-Llama-3-8B-Instruct": 8,
    "Llama-2-7b-chat-hf": 7,
    "Mixtral-8x7B-Instruct-v0.1": 56,
}

folder_path = "Paper Experiment Results/New_filtered/Summary"
output_photo_name = f"IF_{current_time_str}.svg"
output_photo_path = os.path.join(folder_path, output_photo_name)
all_dfs = []
for filename in os.listdir(folder_path):
    if filename.endswith(".csv") and "evaluated" in filename:
        file_path = os.path.join(folder_path, filename)
        df = pd.read_csv(file_path)
        model_name = filename.split("_")[2]
        df["model_name"] = model_name
        df["weight_size"] = model_weight_sizes.get(model_name, None)
        all_dfs.append(df)

df = pd.concat(all_dfs, ignore_index=True)
df["Temperature"] = df["Temperature"].astype(float).round(1)

one_hot_model = pd.get_dummies(df["model_name"], dtype=int)
model_columns = one_hot_model.columns.tolist()
df = pd.concat([df, one_hot_model], axis=1)

model_map = {
    "Llama-2-7b-chat-hf": 0,
    "Llama-2-13b-chat-hf": 1,
    "Llama-2-70b-chat-hf": 2,
    "Meta-Llama-3-8B-Instruct": 3,
    "Meta-Llama-3-70B-Instruct": 4,
    "Mistral-7B-Instruct-v0.2": 5,
    "Mixtral-8x7B-Instruct-v0.1": 6,
}

marker_map = {
    "Llama-2-7b-chat-hf": ".",
    "Llama-2-13b-chat-hf": "*",
    "Llama-2-70b-chat-hf": "o",
    "Meta-Llama-3-8B-Instruct": "+",
    "Meta-Llama-3-70B-Instruct": "^",
    "Mistral-7B-Instruct-v0.2": "<",
    "Mixtral-8x7B-Instruct-v0.1": ">",
}

color_map = {
    "Llama-2-7b-chat-hf": "C0",
    "Llama-2-13b-chat-hf": "C1",
    "Llama-2-70b-chat-hf": "C2",
    "Meta-Llama-3-8B-Instruct": "C3",
    "Meta-Llama-3-70B-Instruct": "C4",
    "Mistral-7B-Instruct-v0.2": "C5",
    "Mixtral-8x7B-Instruct-v0.1": "C6",
}

folder_path = "Paper Experiment Results/New_filtered/Summary"
df["pure_response"] = df["pure_response"].astype(str)
df["pure_response_length"] = df["pure_response"].apply(len)
df["time_per_char"] = df["elapsed_time"] / df["pure_response_length"]
df["initial_prompt_length"] = df["initial_prompt"].apply(len)
df["Temperature"] = df["Temperature"].round(1)
df["model_encoded"] = df["model_name"].map(model_map)

node_labels = [
    "Temperature",
    "model_encoded",
    "initial_prompt_length",
    "rouge_l_fmeasure",
    "time_per_char",
] + model_columns

causal_dataset_df = df[node_labels]

grouped = causal_dataset_df.groupby(["model_encoded", "Temperature"])
train_set = pd.DataFrame()
validation_set = pd.DataFrame()
for name, group in grouped:
    split_index = int(len(group) * 0.6)
    train = group.iloc[:split_index]
    validation = group.iloc[split_index:]
    train_set = pd.concat([train_set, train])
    validation_set = pd.concat([validation_set, validation])

# Temperature Scaling
start = 0.1
stop = 2.1
step = 0.3
control_values = np.arange(start, stop, step)

# %% [markdown]
# At this time we got trainset set and validation set and let's check if that's correct.

# %%
train_counts = (
    train_set[["Temperature", "model_encoded"]].value_counts().unstack(fill_value=0)
)
validation_counts = (
    validation_set[["Temperature", "model_encoded"]]
    .value_counts()
    .unstack(fill_value=0)
)

fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 8))

train_counts.plot(kind="bar", stacked=True, ax=axes[0], title="Train Set Value Counts")
validation_counts.plot(
    kind="bar", stacked=True, ax=axes[1], title="Validation Set Value Counts"
)
axes[0].set_xlabel("Temperature")
axes[0].set_ylabel("Counts")
axes[1].set_xlabel("Temperature")
axes[1].set_ylabel("Counts")

plt.tight_layout()
plt.show()

cols = [
    "initial_prompt_length",
] + model_columns
T_train = train_set["Temperature"].values
X_train = train_set[cols].values
Y_train = train_set["rouge_l_fmeasure"].values
T_val = validation_set["Temperature"].values
X_val = validation_set[cols].values
Y_val = validation_set["rouge_l_fmeasure"].values
T = causal_dataset_df["Temperature"].values
X = causal_dataset_df[cols].values
Y = causal_dataset_df["rouge_l_fmeasure"].values

# %% [markdown]
# Let's start with the first model

# %%
from dowhy import CausalModel
from dowhy.gcm.falsify import falsify_graph

model = CausalModel(
    data=train_set,
    treatment=["Temperature"],
    outcome=["rouge_l_fmeasure"],
    effect_modifiers=cols,
)
model.view_model()

identified_estimand = model.identify_effect()
print(identified_estimand)

result = falsify_graph(
    causal_graph=model._graph._graph,
    data=causal_dataset_df,
    plot_histogram=True,
    n_permutations=1000,
    suggestions=True,
)

dict_summary = result.__dict__["summary"]

keys = list(dict_summary.keys())
if len(keys) >= 2:
    TPA = keys[0]
    LMC = keys[1]

# Graph Refutation 1
p_value_TPA = [
    value for key, value in dict_summary[TPA].items() if "P_VALUE" in key.name
][0]
# Graph Refutation 2
p_value_LMC = [
    value for key, value in dict_summary[LMC].items() if "P_VALUE" in key.name
][0]
# Out:
# Estimand type: EstimandType.NONPARAMETRIC_ATE
#
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#       d
# ──────────────(E[rouge_l_fmeasure])
# d[Temperature]
# Estimand assumption 1, Unconfoundedness: If U→{Temperature} and U→rouge_l_fmeasure then P(rouge_l_fmeasure|Temperature,,U) = P(rouge_l_fmeasure|Temperature,)
#
# ### Estimand : 2
# Estimand name: iv
# No such variable(s) found!
#
# ### Estimand : 3
# Estimand name: frontdoor
# No such variable(s) found!
# /home/lujun/.local/lib/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# /home/lujun/.local/lib/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# /home/lujun/.local/lib/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# /home/lujun/.local/lib/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# /home/lujun/.local/lib/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# /home/lujun/.local/lib/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# /home/lujun/.local/lib/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# /home/lujun/.local/lib/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# /home/lujun/.local/lib/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# /home/lujun/.local/lib/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# /home/lujun/.local/lib/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# /home/lujun/.local/lib/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# /home/lujun/.local/lib/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# /home/lujun/.local/lib/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# /home/lujun/.local/lib/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# /home/lujun/.local/lib/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# /home/lujun/.local/lib/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# /home/lujun/.local/lib/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# /home/lujun/.local/lib/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# /home/lujun/.local/lib/python3.9/site-packages/networkx/utils/backends.py:135: RuntimeWarning: networkx backend defined more than once: nx-loopback
#   backends.update(_get_backends("networkx.backends"))
# Test permutations of given graph: 100%|██████████| 1000/1000 [00:07<00:00, 135.51it/s]

# %%
from sklearn.linear_model import LassoCV, LogisticRegressionCV
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from econml.sklearn_extensions.linear_model import WeightedLassoCV
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from econml.sklearn_extensions.model_selection import GridSearchCVList
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from econml.sklearn_extensions.linear_model import WeightedLasso
from sklearn.base import clone
from econml.dml import DML, LinearDML, SparseLinearDML, NonParamDML

model_y_list = GridSearchCVList(
    [
        Lasso(max_iter=10000),
        RandomForestRegressor(random_state=123),
        GradientBoostingRegressor(random_state=123),
    ],
    param_grid_list=[
        {"alpha": [0.001, 0.01, 0.1, 1, 10]},
        {"max_depth": [3, 5], "min_samples_leaf": [10, 50]},
        {
            "n_estimators": [50, 100],
            "max_depth": [3, 5],
            "min_samples_leaf": [10, 30, 50],
        },
    ],
    cv=5,
    scoring="neg_mean_squared_error",
    n_jobs=-1,  # use parallel
)

model_t_list = GridSearchCVList(
    [
        Lasso(max_iter=10000),
        RandomForestRegressor(n_estimators=100, random_state=123),
        GradientBoostingRegressor(random_state=123),
    ],
    param_grid_list=[
        {"alpha": [0.001, 0.01, 0.1, 1, 10]},
        {"max_depth": [3, 5], "min_samples_leaf": [10, 50]},
        {
            "n_estimators": [50, 100],
            "max_depth": [3, 5],
            "min_samples_leaf": [10, 30, 50],
        },
    ],
    cv=5,
    scoring="neg_mean_squared_error",
    n_jobs=-1,
)


model_final = GridSearchCVList(
    [
        WeightedLasso(max_iter=10000),
        RandomForestRegressor(n_estimators=100, random_state=123),
    ],
    param_grid_list=[
        {"alpha": [0.001, 0.01, 0.1, 1, 10]},
        {"max_depth": [3, 5], "min_samples_leaf": [10, 50]},
        {},
    ],
    cv=5,
    scoring="neg_mean_squared_error",
    n_jobs=-1,
)

featurizer = PolynomialFeatures(degree=3, interaction_only=False, include_bias=False)
model_y_best = model_y_list.fit(X_train, Y_train.ravel()).best_estimator_
model_t_best = model_t_list.fit(X_train, Y_train.ravel()).best_estimator_

dml_estimate_linear = model.estimate_effect(
    identified_estimand,
    method_name="backdoor.econml.dml.LinearDML",
    method_params={
        "init_params": {
            "model_y": "auto",
            "model_t": "auto",
            "treatment_featurizer": featurizer,
            "cv": 5,
        }
    },
    fit_estimator=True,
)

dml_estimate_CausalForest = model.estimate_effect(
    identified_estimand,
    method_name="backdoor.econml.dml.CausalForestDML",
    method_params={
        "init_params": {
            "model_y": "auto",
            "model_t": "auto",
            "treatment_featurizer": featurizer,
            "cv": 5,
            "n_estimators": 2000,
            "random_state": 123,
        }
    },
    fit_estimator=True,
)

dml_estimate_NonParamDML = model.estimate_effect(
    identified_estimand,
    method_name="backdoor.econml.dml.NonParamDML",
    method_params={
        "init_params": {
            "model_y": "auto",
            "model_t": "auto",
            # "treatment_featurizer": featurizer,
            "model_final": model_final,
            "cv": 5,
        }
    },
    fit_estimator=True,
)
# Out:
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 21770.364418102596, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 21276.491998567202, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22053.22813975611, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22386.538009442862, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 21740.78786568385, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 21720.709127410133, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 21916.510880656253, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22764.859279770848, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 20292.93964260332, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 21742.18090340818, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 21896.299829330394, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 20856.41591707424, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22525.434651588625, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22586.26965775798, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22918.573083030737, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22908.45689459091, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22069.739655929377, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 21656.11641368302, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22855.974702825566, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23349.915056776736, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23453.416294258077, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 21480.674442658237, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23783.38734390636, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23430.4004633282, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22834.393951862974, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 20950.450298080723, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 20735.108155714297, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23902.106928939374, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22112.864678781614, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23181.189940452266, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24316.921359839595, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24604.81177537525, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22361.615863148385, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24185.948883485158, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24388.164640564086, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23495.08382541718, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25441.89141563181, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24482.794225325462, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24347.7087877895, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24650.528149693197, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25366.402093084595, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25766.830194746468, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 16395.050934055624, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25131.742969358467, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 20320.01863590935, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23256.24766518712, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24384.254029379506, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25139.35335748253, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23739.864065261892, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26065.54638106635, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26266.606225226187, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26008.462780964383, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22390.675140208587, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26445.116831880423, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25662.888187870594, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26047.435303740524, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25417.891030044088, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26521.735626113026, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25899.82567450058, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26377.719441544614, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25750.551760354352, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26465.286217410958, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26545.245508942404, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26227.91420062173, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26073.695924725173, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26475.236844091913, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26452.5735048959, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26391.800695745053, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26384.851735042972, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26445.958547759517, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26481.3578613439, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26089.582644644994, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26640.41852398464, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26517.062391491367, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26539.689445999986, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26262.308758468924, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26583.789202194457, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24657.58807592286, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25838.617969313003, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26325.63352014049, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26094.69231344761, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26448.820588809882, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26662.791554132757, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26634.956268814218, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26610.07039175803, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26664.650015088413, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26667.499588874794, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26621.73295533677, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26676.94735359947, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26629.26024689639, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26411.452019769837, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26700.90827308062, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26641.042570261732, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26711.619896432258, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26590.809460882814, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26693.00449799754, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26532.921989345814, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26665.31836357897, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26641.058360602357, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26695.877345048422, tolerance: 5.3477639618975905
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22473.667031661276, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22796.57639930916, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 21072.16509459052, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 21784.823156711922, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 21478.212321982654, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22766.429356093846, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22908.82705871529, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23397.22133151057, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 19879.092681606544, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 20993.76800950563, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 21432.15774427049, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 21742.31357938099, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22560.73580734441, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 21610.197744685025, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22912.709813524674, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22779.428545773335, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22554.11925651094, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 18951.523402993396, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23553.321725031303, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24770.217224610322, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22524.02171621861, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23283.26120540709, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23966.49308195278, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24073.403593699502, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 21778.45807870361, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23051.284260975022, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24275.26715006839, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 19987.03534140601, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23330.599161928454, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 19700.079135335443, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 17882.041461556146, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23681.20791406035, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22876.372094638366, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 21205.424228021642, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24767.933987994165, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23987.121580856467, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23123.572393212497, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24621.54410259659, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 20139.16568826902, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25283.16655979218, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25233.809101087576, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25533.17466312307, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24084.18544493681, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24208.773133640698, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26212.601537298615, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24562.60893220951, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24388.41849414988, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26057.762174188272, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23443.698147619383, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26318.31034038762, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26156.952206682938, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25452.39297719825, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26227.412152410165, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26298.434193031382, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26119.596977485173, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26345.528511540495, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26363.79135356444, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25943.61444900805, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26339.572176672897, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25880.82796158581, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26270.085594674812, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26367.00371624258, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26000.60129789918, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26556.422668541705, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26279.849850179806, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26461.593040674936, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26568.154309324527, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26406.669290852144, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26446.66014880118, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26137.268372971932, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26112.00414251848, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26403.31105778274, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26439.20026270307, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26544.08704820615, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26616.003585190396, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26512.771967475503, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26645.74295663558, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26669.251882265227, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26628.385067035924, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26604.605590362415, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26675.189523940007, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26656.56200048412, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26655.683882775225, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26639.84322111416, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26668.03465935381, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26714.500744593093, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26636.604310403356, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26715.814472590195, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26699.118530297736, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26714.81503758115, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26716.599234368336, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26733.193925351086, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26701.002051267016, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26700.31350686149, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26739.50041386414, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26708.603701528224, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26717.6878595094, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26721.30982944246, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26738.64266049763, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26742.98833967999, tolerance: 5.352680214350614
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22568.649828964375, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22760.857169289742, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22856.255191824603, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 21730.974125919394, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23156.423700941334, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22759.630024099668, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23027.232304117642, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23345.987736384996, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23181.38544106362, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22716.336929986617, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22839.85861433867, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22113.264946428455, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22798.3483134295, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22329.42446463854, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24148.866346824336, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23602.40324320346, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22464.505485791753, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22384.432765678466, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23207.146191799544, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22059.471963502172, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22426.063992856034, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23487.37772997833, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22767.703291917554, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24637.59385294643, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23152.49099144194, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23675.1159250682, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 15870.309421460455, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22667.938724936932, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24287.531787057706, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24093.996267658364, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 20972.665956747765, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 18515.41762163341, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24536.920039355875, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24619.114515589852, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24935.190148074696, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25402.90877387169, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25355.397293128564, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 21540.66365666445, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23394.293275590182, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24014.90629835622, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25011.633724145333, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 19395.50804951098, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25076.61972658821, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25571.67461265776, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25822.727846682526, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25809.409631536546, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25746.070051258735, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25219.777720153877, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23867.88190982029, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 24788.68424941886, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25925.40447607203, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26182.04214274655, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25599.622345209147, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25873.62545056228, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25943.550254667138, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26343.700452644895, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26253.692310685696, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26089.6572487038, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26349.7216148817, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26431.12596502578, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26399.072274612165, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25797.972099258724, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26010.12313899738, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 20890.59403928095, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26589.756642986107, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25682.683385855413, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26323.94047263512, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26508.606229766676, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26501.170747225267, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26536.489320068482, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26355.1248279821, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26527.582719023405, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26628.85232426069, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26667.245875297955, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26610.851477281114, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26657.95562293538, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26629.82168202665, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26406.14908035299, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26561.997490947124, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25199.659787532386, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26588.665602137047, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26470.424557620187, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26582.458163287592, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26682.087909835755, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26676.82831874401, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26600.8393854887, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26526.57135531012, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26702.676204446157, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26702.01459536654, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26707.624998393534, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26721.897124129988, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26693.644487884998, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26690.796181697307, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26704.152477225834, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26724.577933118, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26715.44474770383, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26660.785694392795, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26637.969549883852, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26716.91067619243, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 26638.008712623476, tolerance: 5.3524633095445235
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 5221.187958772094, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 7166.891047363057, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 3383.5045907903914, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 15969.534419130128, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 10325.224132965253, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 6523.404885709962, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 11872.164546105556, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 18378.863266748533, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 18042.561745082647, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 4067.075187066792, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 11423.466966925185, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 364.8191433911343, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 20508.78323714778, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 22031.37377293461, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 19940.993082900488, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 20222.842592844107, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 17290.937825050143, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 15977.546524359195, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 14993.958347644986, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 20505.32842207987, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 21975.031470070724, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 15447.364690584807, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 16039.775258953106, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 6229.140583278648, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 18954.89289660107, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 17945.880302185717, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23756.084043863742, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 21893.231715532034, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23569.057075212535, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23073.340025926926, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23776.236656777226, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23973.589359914185, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 25244.51394667592, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 21714.857501027698, tolerance: 5.335535407521691
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23411.192254358677, tolerance: 5.335535407521691
# ...
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1274.0711215562042, tolerance: 0.2550598173361523
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1274.1399585846866, tolerance: 0.2550598173361523
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1274.2041579036245, tolerance: 0.2550598173361523
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1274.2640318608471, tolerance: 0.2550598173361523
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1157.847436619889, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1157.2348634831858, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1156.378156493864, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1155.2704082392263, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1154.333739355959, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1153.4259806670173, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1152.0582971196422, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1150.8466938689946, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1149.7111011034742, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1148.2312783017296, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1146.38037851167, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1144.6688729395808, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1141.9446531655278, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1140.2950439832991, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1137.5041663715579, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1134.9210347387157, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1132.1447847543068, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1127.8679867877465, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1124.3792134479463, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1120.0023435199812, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1115.3111185438777, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1108.677534650126, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1102.8091485349182, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1096.1346180790545, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1085.4193459716305, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1075.9376974880838, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1062.6749566370027, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1047.1731483165388, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1023.9205489244216, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 997.6501899834611, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 963.8022591712306, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 916.5556238441469, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 858.6810760494892, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 721.8654448922821, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 493.50178163195676, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.2029113328953827, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 261.8174444483152, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 637.7864520795669, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 866.3387998038149, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 936.6897700257191, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1024.3610465299812, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1076.2935392174231, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1101.8480503836215, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1134.7378652526475, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1153.1595723262074, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1170.7909497733503, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1182.6091050794973, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1192.9500006204098, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1203.2432822380129, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1210.7153215476462, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1217.6679781975122, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1223.3009662895524, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1229.7237652162528, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1233.3419244665133, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1237.7650817924402, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1241.2435222927465, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1244.5458909213578, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1247.1581019369503, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1249.7903998187358, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1252.0853117598792, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1254.187143093453, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1255.9438519903567, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1257.7243224345013, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1259.3560078396442, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1260.9145558190075, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1262.1657794959372, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1263.4288957126591, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1264.2481002579964, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1265.3428560181567, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1266.3060493317537, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1267.0798397489582, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1267.8016922697916, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1268.5414096814384, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1269.2261207466322, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1269.969826147632, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1270.4975669799796, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1271.0133300768468, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1271.3823641164886, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1271.9582453936457, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1272.4257558183706, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1272.737171379029, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1273.0627064298365, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1273.4712782874672, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1273.749986705734, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1273.972014879553, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1274.3021663663467, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1274.5275896296203, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1274.7487781777143, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1274.9645925947689, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1275.156361611244, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1275.3434417449607, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1275.5173206596428, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1275.6718726510119, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1275.8291395604354, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1275.9687517400398, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1276.0815620569276, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1276.2086899665744, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1276.3068155692006, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1276.4035499035795, tolerance: 0.25562846998308913
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.211e+02, tolerance: 2.570e-01
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.918e+02, tolerance: 2.545e-01
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.438e+02, tolerance: 2.548e-01
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.651e+02, tolerance: 2.551e-01
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.168e+03, tolerance: 2.556e-01

# %%
# est.fit(Y=Y_train, T=T_train.reshape(-1, 1), X=X_train)

# est.models_y[0][1].get_params()
# est.models_y[0][1].feature_importances_

# %%
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import mean_squared_error

# control_temp_values = np.arange(0.1, 2.1, 0.3)
# control_temp = 0.1
# target_temp = control_temp + 0.3


def calculate_true_effect(validation_set, control_temp, target_temp):
    control_data = validation_set[validation_set["Temperature"] == control_temp][
        "rouge_l_fmeasure"
    ].reset_index(drop=True)
    target_data = validation_set[validation_set["Temperature"] == target_temp][
        "rouge_l_fmeasure"
    ].reset_index(drop=True)

    min_length = min(len(control_data), len(target_data))
    control_data = control_data[:min_length]
    target_data = target_data[:min_length]

    if not control_data.empty and not target_data.empty:
        true_effect = target_data - control_data
        ate = true_effect.mean()  # Calculate the average treatment effect (ATE)
    else:
        ate = None

    return ate, min_length


def calculate_ates(validation_set, dml_estimate, calculate_true_effect, is_plot=False):
    """
    Calculate true and predicted Average Treatment Effects (ATEs) for temperature ranges.

    Args:
    validation_set (DataFrame): The validation dataset containing Temperature column.
    dml_estimate (object): The Double Machine Learning estimator object.
    calculate_true_effect (function): Function to calculate the true effect.

    Returns:
    tuple: A tuple containing two lists: true_ates and predict_ates.
    """
    true_ates = []
    predict_ates = []
    temperatures = sorted(validation_set["Temperature"].unique())
    estimator_econml = dml_estimate.estimator.estimator

    for i in range(len(temperatures) - 1):
        control_temp = temperatures[i]
        target_temp = temperatures[i + 1]
        true_ate, min_length = calculate_true_effect(
            validation_set, control_temp, target_temp
        )
        true_ates.append(true_ate)
        predict_ate = estimator_econml.ate(
            X=validation_set[validation_set["Temperature"] == control_temp][cols],
            T0=control_temp,
            T1=target_temp,
        )
        predict_ates.append(predict_ate)

    if is_plot:
        # To see the results of the predictied ATE and true ATE in the validation sets.
        plt.figure(figsize=(10, 6))
        plt.plot(temperatures[:-1], true_ates, label="True ATE", marker="o")
        plt.plot(temperatures[:-1], predict_ates, label="Predicted ATE", marker="x")
        plt.xlabel("Temperature")
        plt.ylabel("ATE")
        plt.title("True ATE vs Predicted ATE by Temperature")
        plt.legend()
        plt.grid(True)
        plt.show()
    return true_ates, predict_ates


true_ates_linear, predict_ates_linear = calculate_ates(
    validation_set, dml_estimate_linear, calculate_true_effect, is_plot=False
)

true_ates_CausalForest, predict_ates_CausalForest = calculate_ates(
    validation_set, dml_estimate_CausalForest, calculate_true_effect, is_plot=False
)
true_ates_NonParamDML, predict_ates_NonParamDML = calculate_ates(
    validation_set, dml_estimate_NonParamDML, calculate_true_effect, is_plot=False
)

# Estimation results on the validation sets.
mse_results = {}

mse_results["linear"] = mean_squared_error(true_ates_linear, predict_ates_linear)
mse_results["CausalForest"] = mean_squared_error(
    true_ates_CausalForest, predict_ates_CausalForest
)
mse_results["NonParamDML"] = mean_squared_error(
    true_ates_NonParamDML, predict_ates_NonParamDML
)

# %%
# Calculate MSE for the best model
true_ates_linear_val, predict_ates_linear_val = calculate_ates(
    validation_set, dml_estimate_linear, calculate_true_effect, is_plot=False
)

true_ates_CausalForest_val, predict_ates_CausalForest_val = calculate_ates(
    validation_set, dml_estimate_CausalForest, calculate_true_effect, is_plot=False
)

true_ates_NonParamDML_val, predict_ates_NonParamDML_val = calculate_ates(
    validation_set, dml_estimate_NonParamDML, calculate_true_effect, is_plot=False
)

true_ates_linear_train, predict_ates_linear_train = calculate_ates(
    train_set, dml_estimate_linear, calculate_true_effect, is_plot=False
)

true_ates_CausalForest_train, predict_ates_CausalForest_train = calculate_ates(
    train_set, dml_estimate_CausalForest, calculate_true_effect, is_plot=False
)

true_ates_NonParamDML_train, predict_ates_NonParamDML_train = calculate_ates(
    train_set, dml_estimate_NonParamDML, calculate_true_effect, is_plot=False
)

mse_results_val = {}

mse_results_val["linear"] = mean_squared_error(
    true_ates_linear_val, predict_ates_linear_val
)
mse_results_val["CausalForest"] = mean_squared_error(
    true_ates_CausalForest_val, predict_ates_CausalForest_val
)
mse_results_val["NonParamDML"] = mean_squared_error(
    true_ates_NonParamDML_val, predict_ates_NonParamDML_val
)

mse_results_train = {}

mse_results_train["linear"] = mean_squared_error(
    true_ates_linear_train, predict_ates_linear_train
)
mse_results_train["CausalForest"] = mean_squared_error(
    true_ates_CausalForest_train, predict_ates_CausalForest_train
)
mse_results_train["NonParamDML"] = mean_squared_error(
    true_ates_NonParamDML_train, predict_ates_NonParamDML_train
)
print(mse_results_train)
print(mse_results_val)
# Not overfitting
# Out:
# {'linear': 142.36744163253528, 'CausalForest': 3.6159358544900716e-05, 'NonParamDML': 6.000382900895377e-06}
# {'linear': 80.67904250994513, 'CausalForest': 3.505100730374365e-05, 'NonParamDML': 9.839502073237847e-06}

# %% [markdown]
# Get parameters of each model

# %%
# use the best model for the final estimation
# calculate_ates(
#     causal_dataset_df[causal_dataset_df["model_encoded"] == 1],
#     dml_estimate_CausalForest,
#     calculate_true_effect,
#     is_plot=False,
# )

model_encodes = sorted(causal_dataset_df["model_encoded"].unique())  # Get unique values

ates_models = {}
model_map = {
    "Llama-2-7b-chat-hf": 0,
    "Llama-2-13b-chat-hf": 1,
    "Llama-2-70b-chat-hf": 2,
    "Meta-Llama-3-8B-Instruct": 3,
    "Meta-Llama-3-70B-Instruct": 4,
    "Mistral-7B-Instruct-v0.2": 5,
    "Mixtral-8x7B-Instruct-v0.1": 6,
}


def find_model_name(model_map, model_encode):
    for key, value in model_map.items():
        if value == model_encode:
            return key
    return None  # Return None if model_name is not found in model_map


for model_encode in model_encodes:
    _, predict_ates = calculate_ates(
        causal_dataset_df[causal_dataset_df["model_encoded"] == model_encode],
        dml_estimate_CausalForest,
        calculate_true_effect,
        is_plot=False,
    )
    model_name = find_model_name(model_map, model_encode)
    ates_models[model_name] = predict_ates

_, predict_avg_ates = calculate_ates(
    causal_dataset_df,
    dml_estimate_CausalForest,
    calculate_true_effect,
    is_plot=False,
)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Plotting the results
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
temperatures = sorted(causal_dataset_df["Temperature"].unique())
for model_name, predict_ates in ates_models.items():
    print(predict_ates)
    plt.plot(
        temperatures[:-1],
        predict_ates,
        label=model_name,
        marker=marker_map[model_name],
        color=color_map[model_name],
        markersize=8,
    )

plt.plot(
    temperatures[:-1],
    predict_avg_ates,
    linestyle="--",
    marker="x",
    markersize=8,
    color="black",
    label="Average Score Among All Models",
)
print(predict_avg_ates)
plt.autoscale()
plt.xlabel("Temperature Scaling")  # Adjust x-axis label as needed
plt.ylabel("ATEs")  # Adjust y-axis label as needed
plt.grid(
    linestyle="--",
)
# plt.title("Average Treatment Effect over Time by Model")  # Adjust title as needed
# plt.legend()  # Show legend with model labels
plt.savefig("SUM.svg", format="svg", bbox_inches="tight")
plt.grid(True)  # Show grid
plt.show()
# Out:
# [0.0008142861173599751, 0.005863311745801871, 0.005852513038914902, 0.0007818899966955463, -0.009348557380852664, -0.024538829093729345]
# [0.00805387264922081, 0.00047118469903586693, -0.004501316585936832, -0.006863631205695234, -0.006615759160241089, -0.00375770044957581]
# [-0.0019498068214647104, -0.003381291212484986, -0.0044440800660581654, -0.005138173382185336, -0.005463571160863169, -0.005420273402095669]
# [0.0015659961200296915, -0.0030331878301112706, -0.005710912794004577, -0.0064671787716507325, -0.005301985763050233, -0.002215333768201253]
# [0.009239201814526294, 0.00032326253885358106, -0.005423327921221861, -0.008000569565701303, -0.007408462394584091, -0.0036470064078734936]
# [0.011230546355963787, 0.0013224440746991484, -0.005565328598489219, -0.0094327716635966, -0.010279885120627092, -0.008106668969573239]
# [0.041893096928034654, -0.0011365974901810516, -0.02356967393975279, -0.025406132420684322, -0.006645972932984856, 0.0327108045233494]
# [0.010121027594808315, 6.130378937371187e-05, -0.0061945895523644896, -0.00864665243040276, -0.007294884844742998, -0.002139286795384295]

# %%
import shap
import matplotlib.pyplot as plt

est = dml_estimate_CausalForest.estimator.estimator
shap_values = est.shap_values(
    X_val,
    feature_names=cols,
)
# Out:
# 100%|===================| 17750/17787 [06:41<00:00]

# %%
import matplotlib.pyplot as pl
import shap

pl.figure(figsize=(30, 10))
shap.plots.beeswarm(
    shap_values["rouge_l_fmeasure"]["Temperature"],
    color=pl.get_cmap("viridis"),
    order=shap_values["rouge_l_fmeasure"]["Temperature"].abs.max(0),
    show=False,
)
pl.savefig("beeswarm_plot.pdf", format="pdf", dpi=700)

# %%
# shap.plots.beeswarm(shap_values["spbleu"]["Temperature"], color="shap_red")

shap.plots.bar(
    shap_values["spbleu"]["Temperature"].mean(0),
    max_display=100,
)

# %% [markdown]
# MAPE is not feasible

# %%
# from sklearn.metrics import mean_absolute_percentage_error

# control_temp = 0.1
# target_temp = 0.4
# estimator_econml = dml_estimate3.estimator.estimator
# predict_effect = estimator_econml.effect(
#     X=validation_set[validation_set["Temperature"] == control_temp][cols],
#     T0=control_temp,
#     T1=target_temp,
# )


# def calculate_true_effect(validation_set, control_temp, target_temp):
#     temp_01_data = validation_set[validation_set["Temperature"] == control_temp][
#         "spbleu"
#     ].reset_index(drop=True)
#     temp_04_data = validation_set[validation_set["Temperature"] == target_temp][
#         "spbleu"
#     ].reset_index(drop=True)

#     min_length = min(len(temp_01_data), len(temp_04_data))
#     temp_01_data = temp_01_data[:min_length]
#     temp_04_data = temp_04_data[:min_length]

#     if not temp_01_data.empty and not temp_04_data.empty:
#         true_effect = temp_01_data - temp_04_data
#     else:
#         true_effect = None

#     return true_effect.values, min_length


# true_effect, min_length = calculate_true_effect(
#     validation_set, control_temp, target_temp
# )
# mape = mean_absolute_percentage_error(true_effect, predict_effect)
# mape
# Out:
# 158387968288377.38

# %%
# Plotting true_effect and predict_effect
plt.figure(figsize=(8, 6))
plt.scatter(range(len(true_effect)), true_effect, color="blue", label="True Effect")
plt.scatter(
    range(len(predict_effect)), predict_effect, color="red", label="Predicted Effect"
)
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("True Effect vs Predicted Effect")
plt.legend()
plt.grid(True)
plt.show()

# %%
max(true_effect)
# Out:
# 29.173244865685128

# %%
from sklearn.linear_model import LassoCV, LogisticRegressionCV
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from econml.sklearn_extensions.linear_model import WeightedLassoCV
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from econml.sklearn_extensions.model_selection import GridSearchCVList
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from econml.sklearn_extensions.linear_model import WeightedLasso
from sklearn.base import clone
from econml.dml import DML, LinearDML, SparseLinearDML, NonParamDML

model_y_list = GridSearchCVList(
    [
        Lasso(max_iter=10000),
        RandomForestRegressor(random_state=123),
        GradientBoostingRegressor(random_state=123),
    ],
    param_grid_list=[
        {"alpha": [0.001, 0.01, 0.1, 1, 10]},
        {"max_depth": [3, 5], "min_samples_leaf": [10, 50]},
        {
            "n_estimators": [50, 100],
            "max_depth": [3, 5],
            "min_samples_leaf": [10, 30, 50],
        },
    ],
    cv=5,
    scoring="neg_mean_squared_error",
    n_jobs=-1,  # use parallel
)

model_t_list = GridSearchCVList(
    [
        Lasso(max_iter=10000),
        RandomForestRegressor(n_estimators=100, random_state=123),
        GradientBoostingRegressor(random_state=123),
    ],
    param_grid_list=[
        {"alpha": [0.001, 0.01, 0.1, 1, 10]},
        {"max_depth": [3, 5], "min_samples_leaf": [10, 50]},
        {
            "n_estimators": [50, 100],
            "max_depth": [3, 5],
            "min_samples_leaf": [10, 30, 50],
        },
    ],
    cv=5,
    scoring="neg_mean_squared_error",
    n_jobs=-1,
)

model_final = GridSearchCVList(
    [
        WeightedLasso(max_iter=10000),
        RandomForestRegressor(n_estimators=100, random_state=123),
    ],
    param_grid_list=[
        {"alpha": [0.001, 0.01, 0.1, 1, 10]},
        {"max_depth": [3, 5], "min_samples_leaf": [10, 50]},
    ],
    cv=5,
    scoring="neg_mean_squared_error",
    n_jobs=-1,
)

featurizer = PolynomialFeatures(degree=3, interaction_only=False, include_bias=False)
model_y_best = model_y_list.fit(X_train, Y_train.ravel()).best_estimator_
model_t_best = model_t_list.fit(X_train, Y_train.ravel()).best_estimator_

dml_estimate = model.estimate_effect(
    identified_estimand,
    method_name="backdoor.econml.dml.LinearDML",
    method_params={
        "init_params": {
            "model_y": model_y_best,
            "model_t": model_t_best,
            # "treatment_featurizer": featurizer,
            "cv": 3,
        }
    },
    fit_estimator=True,
)

dml_estimate2 = model.estimate_effect(
    identified_estimand,
    method_name="backdoor.econml.dml.CausalForestDML",
    method_params={
        "init_params": {
            "model_y": model_y_best,
            "model_t": model_t_best,
            # "treatment_featurizer": featurizer,
            "cv": 3,
            "n_estimators": 2000,
            "random_state": 123,
        }
    },
    fit_estimator=True,
)

dml_estimate3 = model.estimate_effect(
    identified_estimand,
    method_name="backdoor.econml.dml.NonParamDML",
    method_params={
        "init_params": {
            "model_y": model_y_best,
            "model_t": model_t_best,
            # "treatment_featurizer": featurizer,
            "model_final": model_final,
            "cv": 3,
        }
    },
    fit_estimator=True,
)
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# Co-variance matrix is underdetermined. Inference will be invalid!
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %% [markdown]
# Make sure that there is no overfitting to validate DML

# %%
# check overfitting
from sklearn.metrics import accuracy_score, mean_squared_error

y_train_pred = model_y_best.predict(X_train)
t_train_pred = model_t_best.predict(X_train)

y_val_pred = model_y_best.predict(X_val)
t_val_pred = model_t_best.predict(X_val)

y_train_mse = mean_squared_error(Y_train, y_train_pred)
y_val_mse = mean_squared_error(Y_val, y_val_pred)
t_train_mse = mean_squared_error(T_train, t_train_pred)
t_val_mse = mean_squared_error(T_val, t_val_pred)

print(f"Model Y - Training MSE: {y_train_mse}")
print(f"Model Y - Validation MSE: {y_val_mse}")
print(f"Model T - Training MSE: {t_train_mse}")
print(f"Model T - Validation MSE: {t_val_mse}")

# estimator_econml = dml_estimate3.estimator.estimator
# result = estimator_econml.effect(
#     X=validation_set[validation_set["Temperature"] == 0.4][cols], T0=0.1, T1=0.4
# )
# true_effect = (
#     validation_set[validation_set["Temperature"] == 0.1]["spbleu"]
#     - validation_set[validation_set["Temperature"] == 0.4]["spbleu"]
# ).values

# plt.figure(figsize=(12, 8))
# sns.histplot(true_effect, kde=True, bins=10, color="blue", label="True Effect")
# sns.histplot(result, kde=True, bins=10, color="red", label="Estimate Effect")
# plt.title("Distribution of True Effect and Estimate Effect")
# plt.xlabel("Effect")
# plt.ylabel("Frequency")
# plt.legend()
# plt.show()
# Out:
# Model Y - Training MSE: 66.11000320860333
# Model Y - Validation MSE: 128.3450612078267
# Model T - Training MSE: 223.29892231106444
# Model T - Validation MSE: 181.45872917417483

# %%
true_effect
# Out:
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3      0.000000
# 4      0.000000
#          ...
# 835    2.121010
# 836    0.125461
# 837    3.353148
# 838    0.000000
# 839    0.000000
# Name: spbleu, Length: 840, dtype: float64

# %%
def regressor_stage():
    return GridSearchCVList(
        [
            Lasso(),
            RandomForestRegressor(n_estimators=100, random_state=123),
            GradientBoostingRegressor(random_state=123),
        ],
        param_grid_list=[
            {"alpha": [0.001, 0.01, 0.1, 1, 10]},
            {"max_depth": [3, None], "min_samples_leaf": [10, 50]},
            {"n_estimators": [50, 100], "max_depth": [3], "min_samples_leaf": [10, 30]},
        ],
        cv=5,
        scoring="neg_mean_squared_error",
    )


model_final = GridSearchCVList(
    [WeightedLasso(), RandomForestRegressor(n_estimators=100, random_state=123)],
    param_grid_list=[
        {"alpha": [0.001, 0.01, 0.1, 1, 10]},
        {"max_depth": [3, 5], "min_samples_leaf": [10, 50]},
    ],
    cv=5,
    scoring="neg_mean_squared_error",
)


# Best fit the model y and model t and copy the best estimator
model_y = clone(regressor_stage().fit(X_train, Y_train).best_estimator_)
model_t = clone(regressor_stage().fit(X_train, T_train).best_estimator_)
featurizer = PolynomialFeatures(degree=4, interaction_only=False, include_bias=False)
# reg = lambda: RandomForestRegressor(min_samples_leaf=10)
# model_y = reg()
# model_t = reg()

models = [
    (
        "ldml",
        LinearDML(
            model_y=model_y,
            model_t=model_t,
            # featurizer=featurizer,
            treatment_featurizer=featurizer,
            cv=3,
        ),
    ),
    (
        "sldml",
        SparseLinearDML(
            model_y=model_y,
            model_t=model_t,
            # featurizer=featurizer,
            treatment_featurizer=featurizer,
            cv=3,
        ),
    ),
    (
        "forestDML",
        CausalForestDML(
            model_y=model_y,
            model_t=model_t,
            # featurizer=featurizer,
            cv=3,
            treatment_featurizer=featurizer,
            n_estimators=2000,
            random_state=123,
        ),
    ),
    (
        "NonParamDML",
        NonParamDML(
            model_y=model_y,
            model_t=model_t,
            # featurizer=featurizer,
            model_final=model_final,
            treatment_featurizer=featurizer,  # No featurizer it can work really well
            cv=3,
        ),
    ),
]
# Out:
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.326e+04, tolerance: 1.531e+02

# %% [markdown]
# Lets start finding the best model with featurizer

# %%
name, mdl = models[1]
mdl.fit(Y=Y_train.reshape(-1, 1), T=T_train.reshape(-1, 1), X=X_train)
# Out:
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.789e+05, tolerance: 6.067e+04
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 15.472875430076925, tolerance: 0.023766751943177917
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.7703641103701955, tolerance: 0.02160268734512278
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 5.016958780502819, tolerance: 0.021623220571010182
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 23.304664324817907, tolerance: 0.13046904947376448
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.0215326581466115, tolerance: 0.06327546052539006
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.26825831809031797, tolerance: 0.19385142300691532
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 11.57964186086042, tolerance: 0.1178205120044758
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.27242241156045566, tolerance: 0.19369671274030217
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.26097634748151677, tolerance: 0.19303357396897533
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2670149174582548, tolerance: 0.19374679004465922
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.36037944906138364, tolerance: 0.31686864499649364
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3522742791519704, tolerance: 0.31700673048213635
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.33398838020639, tolerance: 0.7112357885370477
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7798465583041434, tolerance: 0.7112357885370477
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 10.349271638752725, tolerance: 0.7110048671166825
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.894058426625634, tolerance: 0.7107666442223163
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 14.208401133909774, tolerance: 0.7107666442223163
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 13.577616687212185, tolerance: 0.2266057743911426
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 9.69968208366754, tolerance: 0.7108563132252033
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 34.100582048637875, tolerance: 0.7079241132259314
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.47710337555577, tolerance: 0.7109465675239808
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 35.784700795258686, tolerance: 1.8584589897465136
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 136.19655761293052, tolerance: 0.694717668039046
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.0, tolerance: 0.0
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 0.000e+00, tolerance: 0.000e+00
# divide by zero encountered in divide
# invalid value encountered in matmul
# invalid value encountered in matmul
# The final model has a nonzero intercept for at least one outcome; it will be subtracted, but consider fitting a model without an intercept if possible.

# %%
T_draw = np.linspace(0, 2, 100)
X_draw = np.zeros((100, 13))
X_draw[:, 0] = 1000
X_draw[:, 2] = 1
X_draw[:, 6] = 1

pred = mdl.ate(X=X_val, T0=0, T1=0.3)
lb, ub = mdl.effect_interval(
    X_val, alpha=0.01
)  # Get the prediction upper bound lower bound

# pre_ate = est2.ate(X=X_val, T0=0, T1=T_draw)
# effect_draw = est2.effect(X=X_draw, T0=0, T1=T_draw)
# marginal_effect_draw = est2.marginal_effect(T=T_draw, X=X_draw)
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(T_val, pred, label="Effect of Treatment")
plt.xlabel("T_test")
plt.ylabel("Output")
plt.title("Effect of Treatment over T_test")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 18
#      15 import matplotlib.pyplot as plt
#      17 plt.figure(figsize=(10, 6))
# ---> 18 plt.scatter(T_val, pred, label="Effect of Treatment")
#      19 plt.xlabel("T_test")
#      20 plt.ylabel("Output")
#
# File ~/anaconda3/envs/causalLLM/lib/python3.9/site-packages/matplotlib/pyplot.py:3687, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3668 @_copy_docstring_and_deprecators(Axes.scatter)
#    3669 def scatter(
#    3670     x: float | ArrayLike,
#    (...)
#    3685     **kwargs,
#    3686 ) -> PathCollection:
# -> 3687     __ret = gca().scatter(
#    3688         x,
#    3689         y,
#    3690         s=s,
#    3691         c=c,
#    3692         marker=marker,
#    3693         cmap=cmap,
#    3694         norm=norm,
#    3695         vmin=vmin,
#    3696         vmax=vmax,
#    3697         alpha=alpha,
#    3698         linewidths=linewidths,
#    3699         edgecolors=edgecolors,
#    3700         plotnonfinite=plotnonfinite,
#    3701         **({"data": data} if data is not None else {}),
#    3702         **kwargs,
#    3703     )
#    3704     sci(__ret)
#    3705     return __ret
#
# File ~/anaconda3/envs/causalLLM/lib/python3.9/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/envs/causalLLM/lib/python3.9/site-packages/matplotlib/axes/_axes.py:4652, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4650 y = np.ma.ravel(y)
#    4651 if x.size != y.size:
# -> 4652     raise ValueError("x and y must be the same size")
#    4654 if s is None:
#    4655     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    4656          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size

# %%
est = CausalForestDML(
    model_y=model_y,
    model_t=model_t,
    cv=3,
    n_estimators=4000,
    random_state=123,
)
est.ate()
# Fit the final model
est.tune(Y_train, T_train.reshape(-1, 1), X=X_train).fit(
    Y_train, T_train, X=X_train, cache_values=True
)

est1 = LinearDML(model_y=model_y, model_t=model_t, treatment_featurizer=featurizer)
effect
#     model_t=model_t,
#     cv=3,
#     mc_iters=3,
#     mc_agg="median",
# )
# scorer.fit(y=Y_train, T=T_train.reshape(-1, 1), X=X_train)

# scorer.score(est1)  # Get the R squer scroe

# pred = est1.effect(X=X_val)
# lb, ub = est.effect_interval(
#     X_val, alpha=0.01
# )  # Get the prediction upper bound lower bound

plt.figure(figsize=(10, 6))
test_T = np.arange(0, 2, step=0.1).reshape(-1, 1)

# Plot point estimates
plt.plot(
    test_T,
    est1.effect(T0=0, T1=test_T),
    label="Estimate with Featurized Treatment",
    linewidth=3,
)


from econml.dml import DML, LinearDML, SparseLinearDML, NonParamDML

est2 = DML(
    model_y=model_y,
    model_t=RandomForestRegressor(),
    model_final=LassoCV(fit_intercept=False),
    featurizer=PolynomialFeatures(degree=3, interaction_only=False, include_bias=False),
    cv=3,
)

est2.fit(Y=Y_train, T=T_train, X=X_train)

from econml.score import RScorer

scorer = RScorer(
    model_y=model_y,
    model_t=model_t,
    cv=3,
    mc_iters=3,
    mc_agg="median",
)
scorer.fit(Y_val, T_val, X=X_val)

scorer.score(est2)  # Get the R squer scroe


T_draw = np.linspace(0, 2, 5880)
X_draw = np.zeros((100, 13))
X_draw[:, 0] = 1000
X_draw[:, 2] = 1
X_draw[:, 6] = 1
pred = est2.effect(X=X_val, T0=0, T1=T_draw)
lb, ub = est.effect_interval(
    X_val, alpha=0.01
)  # Get the prediction upper bound lower bound

# pre_ate = est2.ate(X=X_val, T0=0, T1=T_draw)
# effect_draw = est2.effect(X=X_draw, T0=0, T1=T_draw)
# marginal_effect_draw = est2.marginal_effect(T=T_draw, X=X_draw)
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(T_draw, pred, label="Effect of Treatment")
plt.xlabel("T_test")
plt.ylabel("Output")
plt.title("Effect of Treatment over T_test")
plt.legend()
plt.grid(True)
plt.show()

effect_draw = est2.ate(X=X_val, T0=0, T1=0.5)
T_draw = np.linspace(0, 2, 100)
X_draw = np.zeros((100, 13))
X_draw[:, 0] = 500
X_draw[:, 2] = 1
X_draw[:, 6] = 1

effect_draw = est.effect(X=X_draw, T0=0, T1=T_draw)
marginal_effect_draw = est.marginal_effect(T=T_draw, X=X_draw)


import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(T_draw, marginal_effect_draw, label="Effect of Treatment")
plt.xlabel("T_test")
plt.ylabel("Output")
plt.title("Effect of Treatment over T_test")
plt.legend()
plt.grid(True)
plt.show()


import shap

shap_values = est2.shap_values(
    X_train,
    feature_names=[
        "initial_prompt_length",
    ]
    + model_columns
    + dataset_columns,
)

shap.plots.beeswarm(shap_values["Y0"]["T0"], max_display=100)
# Out:
# Co-variance matrix is underdetermined. Inference will be invalid!
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[56], line 29
#      24 test_T = np.arange(0, 2, step=0.1).reshape(-1, 1)
#      26 # Plot point estimates
#      27 plt.plot(
#      28     test_T,
# ---> 29     est1.effect(T0=0, T1=test_T),
#      30     label="Estimate with Featurized Treatment",
#      31     linewidth=3,
#      32 )
#
# File ~/anaconda3/envs/causalLLM/lib/python3.9/site-packages/econml/_cate_estimator.py:914, in TreatmentExpansionMixin.effect(self, X, T0, T1)
#     912 def effect(self, X=None, *, T0=0, T1=1):
#     913     # NOTE: don't explicitly expand treatments here, because it's done in the super call
# --> 914     return super().effect(X, T0=T0, T1=T1)
#
# File ~/anaconda3/envs/causalLLM/lib/python3.9/site-packages/econml/_cate_estimator.py:603, in LinearCateEstimator.effect(self, X, T0, T1)
#     600 X, T0, T1 = self._expand_treatments(X, T0, T1)
#     601 # TODO: what if input is sparse? - there's no equivalent to einsum,
#     602 #       but tensordot can't be applied to this problem because we don't sum over m
# --> 603 eff = self.const_marginal_effect(X)
#     604 # if X is None then the shape of const_marginal_effect will be wrong because the number
#     605 # of rows of T was not taken into account
#     606 if X is None:
#
# File ~/anaconda3/envs/causalLLM/lib/python3.9/site-packages/econml/_ortho_learner.py:1005, in _OrthoLearner.const_marginal_effect(self, X)
#    1003 def const_marginal_effect(self, X=None):
#    1004     X, = check_input_arrays(X)
# -> 1005     self._check_fitted_dims(X)
#    1006     if X is None:
#    1007         return self._ortho_learner_model_final.predict()
#
# File ~/anaconda3/envs/causalLLM/lib/python3.9/site-packages/econml/_ortho_learner.py:659, in _OrthoLearner._check_fitted_dims(self, X)
#     657 def _check_fitted_dims(self, X):
#     658     if X is None:
# --> 659         assert self._d_x is None, "X was not None when fitting, so can't be none for score or effect"
#     660     else:
#     661         assert self._d_x == X.shape[1:], "Dimension mis-match of X with fitted X"
#
# AssertionError: X was not None when fitting, so can't be none for score or effect

# %%
# Define some parameters
n_trees = 1000
min_leaf_size = 50
max_depth = 20
subsample_ratio = 0.04

# %%
# # Main imports
# from econml.sklearn_extensions.linear_model import (
#     WeightedLassoCVWrapper,
#     WeightedLasso,
#     WeightedLassoCV,
# )
# from econml.orf import DMLOrthoForest, DROrthoForest

# est3 = DMLOrthoForest(
#     n_trees=n_trees,
#     min_leaf_size=min_leaf_size,
#     max_depth=max_depth,
#     subsample_ratio=subsample_ratio,
#     model_T=Lasso(alpha=0.1),
#     model_Y=Lasso(alpha=0.1),
#     model_T_final=WeightedLassoCVWrapper(cv=3),
#     model_Y_final=WeightedLassoCVWrapper(cv=3),
# )

# est3.fit(Y=Y_train, T=T_train, X=X_train)

# # Calculate treatment effects for the default treatment points T0=0 and T1=1
# treatment_effects = est3.effect(T0=0, T1=T_draw)
# te_lower, te_upper = est3.effect_interval(T0=0, T1=T_draw)

# %%
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 20 concurrent workers.
# networkx backend defined more than once: nx-loopback
# networkx backend defined more than once: nx-loopback
# networkx backend defined more than once: nx-loopback
# networkx backend defined more than once: nx-loopback
# networkx backend defined more than once: nx-loopback
# networkx backend defined more than once: nx-loopback
# networkx backend defined more than once: nx-loopback
# networkx backend defined more than once: nx-loopback
# networkx backend defined more than once: nx-loopback
# networkx backend defined more than once: nx-loopback
# networkx backend defined more than once: nx-loopback
# networkx backend defined more than once: nx-loopback
# networkx backend defined more than once: nx-loopback
# networkx backend defined more than once: nx-loopback
# networkx backend defined more than once: nx-loopback
# networkx backend defined more than once: nx-loopback
# networkx backend defined more than once: nx-loopback
# networkx backend defined more than once: nx-loopback
# networkx backend defined more than once: nx-loopback
# networkx backend defined more than once: nx-loopback
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed:   27.3s
# [Parallel(n_jobs=-1)]: Done 1000 out of 1000 | elapsed:   27.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 20 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 156 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 1000 out of 1000 | elapsed:    0.5s finished

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(T_draw, treatment_effects, label="Effect of Treatment")
plt.xlabel("T_test")
plt.ylabel("Output")
plt.title("Effect of Treatment over T_test")
plt.legend()
plt.grid(True)
plt.show()
